# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 3
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 3:
# Image - Min Value: 4 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return np.array(x) / 255.0


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import OneHotEncoder

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    one_hot_encoded = np.zeros((len(x), 10))
    for i in range(len(x)):
        one_hot_encoded[i][x[i]] = 1.0
    return one_hot_encoded


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # Create filter dimensions
    filter_height, filter_width, in_channels, out_channels = \
        conv_ksize[0], conv_ksize[1],  x_tensor.get_shape().as_list()[3], conv_num_outputs
    conv_filter = [filter_height, filter_width, in_channels, out_channels]
    
    # Create weights and bias
    weights = tf.Variable(tf.truncated_normal(conv_filter, stddev=0.05))
    bias = tf.Variable(tf.truncated_normal([conv_num_outputs], stddev=0.05))
    
    # Create strides
    strides=(1,conv_strides[0], conv_strides[1], 1)
    
    conv = tf.nn.conv2d(x_tensor, weights, strides, padding='SAME')
    conv = tf.nn.bias_add(conv, bias)    
    
    # Create ksize 
    ksize = (1, pool_ksize[0], pool_ksize[1], 1)
    
    # Create strides
    strides=(1,pool_strides[0], pool_strides[1], 1)
    
    pool = tf.nn.max_pool(conv, ksize, strides, padding='SAME')
    
    print('conv_num_outputs:',conv_num_outputs,
          'conv_ksize:', conv_ksize,
          'conv_strides:', conv_strides,
          'pool_ksize:',pool_ksize,
          'pool_strides', pool_strides,
          'layer shape', pool.get_shape().as_list())
    
    return pool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# conv_num_outputs: 10 conv_ksize: (2, 2) conv_strides: (4, 4) pool_ksize: (2, 2) pool_strides (2, 2) layer shape [None, 4, 4, 10]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    
    _, height, width, channels = x_tensor.get_shape().as_list()
    net = tf.reshape(x_tensor, shape=[-1, height * width * channels])
    print('flatten shape', net.get_shape().as_list())
    return net

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# flatten shape [None, 1800]
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    _, size = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal([size, num_outputs], stddev=0.05))
    bias = tf.Variable(tf.truncated_normal([num_outputs], stddev=0.05))
    

    fully_connected = tf.add(tf.matmul(x_tensor, weights), bias)
    return fully_connected


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return fully_conn(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    # conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    net = conv2d_maxpool(x,   32, (7,7), (2,2), (2,2), (2,2))
    net = conv2d_maxpool(net, 64, (3,3), (1,1), (2,2), (2,2))
    net = conv2d_maxpool(net, 128, (2,2), (1,1), (2,2), (2,2))
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    net = flatten(net)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    net = tf.nn.dropout(net, keep_prob)
    net = fully_conn(net, 1024)
    net = tf.nn.dropout(net, keep_prob)
    net = fully_conn(net, 128)

    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    net = output(net, 10)
    
    # TODO: return output
    return net


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# conv_num_outputs: 32 conv_ksize: (7, 7) conv_strides: (2, 2) pool_ksize: (2, 2) pool_strides (2, 2) layer shape [None, 8, 8, 32]
# conv_num_outputs: 64 conv_ksize: (3, 3) conv_strides: (1, 1) pool_ksize: (2, 2) pool_strides (2, 2) layer shape [None, 4, 4, 64]
# conv_num_outputs: 128 conv_ksize: (2, 2) conv_strides: (1, 1) pool_ksize: (2, 2) pool_strides (2, 2) layer shape [None, 2, 2, 128]
# flatten shape [None, 512]
# conv_num_outputs: 32 conv_ksize: (7, 7) conv_strides: (2, 2) pool_ksize: (2, 2) pool_strides (2, 2) layer shape [None, 8, 8, 32]
# conv_num_outputs: 64 conv_ksize: (3, 3) conv_strides: (1, 1) pool_ksize: (2, 2) pool_strides (2, 2) layer shape [None, 4, 4, 64]
# conv_num_outputs: 128 conv_ksize: (2, 2) conv_strides: (1, 1) pool_ksize: (2, 2) pool_strides (2, 2) layer shape [None, 2, 2, 128]
# flatten shape [None, 512]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    return session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    batch_loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    batch_accuracy = session.run(accuracy, feed_dict={x:valid_features, y:valid_labels, keep_prob:1.0})
    
    print('batch loss is : ', batch_loss)
    print('batch_accuracy accuracy is :',batch_accuracy)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  batch loss is :  2.01621
# batch_accuracy accuracy is : 0.3516
# Epoch  2, CIFAR-10 Batch 1:  batch loss is :  1.79829
# batch_accuracy accuracy is : 0.3936
# Epoch  3, CIFAR-10 Batch 1:  batch loss is :  1.59528
# batch_accuracy accuracy is : 0.4118
# Epoch  4, CIFAR-10 Batch 1:  batch loss is :  1.33808
# batch_accuracy accuracy is : 0.4564
# Epoch  5, CIFAR-10 Batch 1:  batch loss is :  1.13682
# batch_accuracy accuracy is : 0.476
# Epoch  6, CIFAR-10 Batch 1:  batch loss is :  1.01696
# batch_accuracy accuracy is : 0.4736
# Epoch  7, CIFAR-10 Batch 1:  batch loss is :  0.855971
# batch_accuracy accuracy is : 0.5108
# Epoch  8, CIFAR-10 Batch 1:  batch loss is :  0.791756
# batch_accuracy accuracy is : 0.506
# Epoch  9, CIFAR-10 Batch 1:  batch loss is :  0.665355
# batch_accuracy accuracy is : 0.5224
# Epoch 10, CIFAR-10 Batch 1:  batch loss is :  0.665342
# batch_accuracy accuracy is : 0.484
# Epoch 11, CIFAR-10 Batch 1:  batch loss is :  0.57644
# batch_accuracy accuracy is : 0.5444
# Epoch 12, CIFAR-10 Batch 1:  batch loss is :  0.513741
# batch_accuracy accuracy is : 0.514
# Epoch 13, CIFAR-10 Batch 1:  batch loss is :  0.420008
# batch_accuracy accuracy is : 0.5324
# Epoch 14, CIFAR-10 Batch 1:  batch loss is :  0.352543
# batch_accuracy accuracy is : 0.5536
# Epoch 15, CIFAR-10 Batch 1:  batch loss is :  0.375497
# batch_accuracy accuracy is : 0.5096
# Epoch 16, CIFAR-10 Batch 1:  batch loss is :  0.260852
# batch_accuracy accuracy is : 0.5478
# Epoch 17, CIFAR-10 Batch 1:  batch loss is :  0.252006
# batch_accuracy accuracy is : 0.5358
# Epoch 18, CIFAR-10 Batch 1:  batch loss is :  0.226451
# batch_accuracy accuracy is : 0.5576
# Epoch 19, CIFAR-10 Batch 1:  batch loss is :  0.205102
# batch_accuracy accuracy is : 0.5332
# Epoch 20, CIFAR-10 Batch 1:  batch loss is :  0.205438
# batch_accuracy accuracy is : 0.5574
# Epoch 21, CIFAR-10 Batch 1:  batch loss is :  0.172188
# batch_accuracy accuracy is : 0.5586
# Epoch 22, CIFAR-10 Batch 1:  batch loss is :  0.190122
# batch_accuracy accuracy is : 0.5746
# Epoch 23, CIFAR-10 Batch 1:  batch loss is :  0.127607
# batch_accuracy accuracy is : 0.5556
# Epoch 24, CIFAR-10 Batch 1:  batch loss is :  0.154031
# batch_accuracy accuracy is : 0.5582
# Epoch 25, CIFAR-10 Batch 1:  batch loss is :  0.129699
# batch_accuracy accuracy is : 0.5662
# Epoch 26, CIFAR-10 Batch 1:  batch loss is :  0.144755
# batch_accuracy accuracy is : 0.563
# Epoch 27, CIFAR-10 Batch 1:  batch loss is :  0.123555
# batch_accuracy accuracy is : 0.5676
# Epoch 28, CIFAR-10 Batch 1:  batch loss is :  0.0824221
# batch_accuracy accuracy is : 0.5654
# Epoch 29, CIFAR-10 Batch 1:  batch loss is :  0.0949605
# batch_accuracy accuracy is : 0.5458
# Epoch 30, CIFAR-10 Batch 1:  batch loss is :  0.0724589
# batch_accuracy accuracy is : 0.5396
# Epoch 31, CIFAR-10 Batch 1:  batch loss is :  0.0494935
# batch_accuracy accuracy is : 0.5622
# Epoch 32, CIFAR-10 Batch 1:  batch loss is :  0.0717434
# batch_accuracy accuracy is : 0.5458
# Epoch 33, CIFAR-10 Batch 1:  batch loss is :  0.078983
# batch_accuracy accuracy is : 0.554
# Epoch 34, CIFAR-10 Batch 1:  batch loss is :  0.0672941
# batch_accuracy accuracy is : 0.5636
# Epoch 35, CIFAR-10 Batch 1:  batch loss is :  0.0708035
# batch_accuracy accuracy is : 0.5644
# Epoch 36, CIFAR-10 Batch 1:  batch loss is :  0.0527931
# batch_accuracy accuracy is : 0.573
# Epoch 37, CIFAR-10 Batch 1:  batch loss is :  0.0509678
# batch_accuracy accuracy is : 0.5734
# Epoch 38, CIFAR-10 Batch 1:  batch loss is :  0.0499897
# batch_accuracy accuracy is : 0.5766
# Epoch 39, CIFAR-10 Batch 1:  batch loss is :  0.0579758
# batch_accuracy accuracy is : 0.5518
# Epoch 40, CIFAR-10 Batch 1:  batch loss is :  0.0380647
# batch_accuracy accuracy is : 0.5772
# Epoch 41, CIFAR-10 Batch 1:  batch loss is :  0.0340027
# batch_accuracy accuracy is : 0.5564
# Epoch 42, CIFAR-10 Batch 1:  batch loss is :  0.0376539
# batch_accuracy accuracy is : 0.5668
# Epoch 43, CIFAR-10 Batch 1:  batch loss is :  0.0306519
# batch_accuracy accuracy is : 0.5728
# Epoch 44, CIFAR-10 Batch 1:  batch loss is :  0.043985
# batch_accuracy accuracy is : 0.5622
# Epoch 45, CIFAR-10 Batch 1:  batch loss is :  0.0276636
# batch_accuracy accuracy is : 0.5724
# Epoch 46, CIFAR-10 Batch 1:  batch loss is :  0.0260448
# batch_accuracy accuracy is : 0.565
# Epoch 47, CIFAR-10 Batch 1:  batch loss is :  0.019529
# batch_accuracy accuracy is : 0.5646
# Epoch 48, CIFAR-10 Batch 1:  batch loss is :  0.0241039
# batch_accuracy accuracy is : 0.5712
# Epoch 49, CIFAR-10 Batch 1:  batch loss is :  0.0230553
# batch_accuracy accuracy is : 0.581
# Epoch 50, CIFAR-10 Batch 1:  batch loss is :  0.022235
# batch_accuracy accuracy is : 0.5752

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  batch loss is :  2.00304
# batch_accuracy accuracy is : 0.323
# Epoch  1, CIFAR-10 Batch 2:  batch loss is :  1.75054
# batch_accuracy accuracy is : 0.394
# Epoch  1, CIFAR-10 Batch 3:  batch loss is :  1.35149
# batch_accuracy accuracy is : 0.4046
# Epoch  1, CIFAR-10 Batch 4:  batch loss is :  1.50867
# batch_accuracy accuracy is : 0.471
# Epoch  1, CIFAR-10 Batch 5:  batch loss is :  1.57831
# batch_accuracy accuracy is : 0.501
# Epoch  2, CIFAR-10 Batch 1:  batch loss is :  1.45653
# batch_accuracy accuracy is : 0.506
# Epoch  2, CIFAR-10 Batch 2:  batch loss is :  1.29823
# batch_accuracy accuracy is : 0.5106
# Epoch  2, CIFAR-10 Batch 3:  batch loss is :  1.03475
# batch_accuracy accuracy is : 0.5172
# Epoch  2, CIFAR-10 Batch 4:  batch loss is :  1.20461
# batch_accuracy accuracy is : 0.5438
# Epoch  2, CIFAR-10 Batch 5:  batch loss is :  1.35019
# batch_accuracy accuracy is : 0.5448
# Epoch  3, CIFAR-10 Batch 1:  batch loss is :  1.12422
# batch_accuracy accuracy is : 0.4972
# Epoch  3, CIFAR-10 Batch 2:  batch loss is :  1.04993
# batch_accuracy accuracy is : 0.5356
# Epoch  3, CIFAR-10 Batch 3:  batch loss is :  0.886404
# batch_accuracy accuracy is : 0.5712
# Epoch  3, CIFAR-10 Batch 4:  batch loss is :  0.947868
# batch_accuracy accuracy is : 0.5594
# Epoch  3, CIFAR-10 Batch 5:  batch loss is :  1.15298
# batch_accuracy accuracy is : 0.5654
# Epoch  4, CIFAR-10 Batch 1:  batch loss is :  0.974473
# batch_accuracy accuracy is : 0.5722
# Epoch  4, CIFAR-10 Batch 2:  batch loss is :  0.814554
# batch_accuracy accuracy is : 0.5508
# Epoch  4, CIFAR-10 Batch 3:  batch loss is :  0.752656
# batch_accuracy accuracy is : 0.5982
# Epoch  4, CIFAR-10 Batch 4:  batch loss is :  0.892644
# batch_accuracy accuracy is : 0.5786
# Epoch  4, CIFAR-10 Batch 5:  batch loss is :  0.960732
# batch_accuracy accuracy is : 0.5854
# Epoch  5, CIFAR-10 Batch 1:  batch loss is :  0.861139
# batch_accuracy accuracy is : 0.588
# Epoch  5, CIFAR-10 Batch 2:  batch loss is :  0.719274
# batch_accuracy accuracy is : 0.5994
# Epoch  5, CIFAR-10 Batch 3:  batch loss is :  0.663918
# batch_accuracy accuracy is : 0.604
# Epoch  5, CIFAR-10 Batch 4:  batch loss is :  0.785833
# batch_accuracy accuracy is : 0.597
# Epoch  5, CIFAR-10 Batch 5:  batch loss is :  0.900774
# batch_accuracy accuracy is : 0.5874
# Epoch  6, CIFAR-10 Batch 1:  batch loss is :  0.762306
# batch_accuracy accuracy is : 0.6034
# Epoch  6, CIFAR-10 Batch 2:  batch loss is :  0.639358
# batch_accuracy accuracy is : 0.6234
# Epoch  6, CIFAR-10 Batch 3:  batch loss is :  0.59943
# batch_accuracy accuracy is : 0.604
# Epoch  6, CIFAR-10 Batch 4:  batch loss is :  0.691322
# batch_accuracy accuracy is : 0.6174
# Epoch  6, CIFAR-10 Batch 5:  batch loss is :  0.719435
# batch_accuracy accuracy is : 0.6072
# Epoch  7, CIFAR-10 Batch 1:  batch loss is :  0.716419
# batch_accuracy accuracy is : 0.6188
# Epoch  7, CIFAR-10 Batch 2:  batch loss is :  0.605016
# batch_accuracy accuracy is : 0.6168
# Epoch  7, CIFAR-10 Batch 3:  batch loss is :  0.620856
# batch_accuracy accuracy is : 0.6068
# Epoch  7, CIFAR-10 Batch 4:  batch loss is :  0.657884
# batch_accuracy accuracy is : 0.6234
# Epoch  7, CIFAR-10 Batch 5:  batch loss is :  0.6961
# batch_accuracy accuracy is : 0.6194
# Epoch  8, CIFAR-10 Batch 1:  batch loss is :  0.585902
# batch_accuracy accuracy is : 0.63
# Epoch  8, CIFAR-10 Batch 2:  batch loss is :  0.549137
# batch_accuracy accuracy is : 0.6186
# Epoch  8, CIFAR-10 Batch 3:  batch loss is :  0.470548
# batch_accuracy accuracy is : 0.6388
# Epoch  8, CIFAR-10 Batch 4:  batch loss is :  0.616317
# batch_accuracy accuracy is : 0.6412
# Epoch  8, CIFAR-10 Batch 5:  batch loss is :  0.594691
# batch_accuracy accuracy is : 0.6244
# Epoch  9, CIFAR-10 Batch 1:  batch loss is :  0.597083
# batch_accuracy accuracy is : 0.6462
# Epoch  9, CIFAR-10 Batch 2:  batch loss is :  0.484251
# batch_accuracy accuracy is : 0.6326
# Epoch  9, CIFAR-10 Batch 3:  batch loss is :  0.485648
# batch_accuracy accuracy is : 0.636
# Epoch  9, CIFAR-10 Batch 4:  batch loss is :  0.569252
# batch_accuracy accuracy is : 0.6392
# Epoch  9, CIFAR-10 Batch 5:  batch loss is :  0.494673
# batch_accuracy accuracy is : 0.6398
# Epoch 10, CIFAR-10 Batch 1:  batch loss is :  0.554709
# batch_accuracy accuracy is : 0.653
# Epoch 10, CIFAR-10 Batch 2:  batch loss is :  0.477346
# batch_accuracy accuracy is : 0.6362
# Epoch 10, CIFAR-10 Batch 3:  batch loss is :  0.427147
# batch_accuracy accuracy is : 0.6476
# Epoch 10, CIFAR-10 Batch 4:  batch loss is :  0.500345
# batch_accuracy accuracy is : 0.6438
# Epoch 10, CIFAR-10 Batch 5:  batch loss is :  0.496783
# batch_accuracy accuracy is : 0.6402
# Epoch 11, CIFAR-10 Batch 1:  batch loss is :  0.48769
# batch_accuracy accuracy is : 0.6598
# Epoch 11, CIFAR-10 Batch 2:  batch loss is :  0.423634
# batch_accuracy accuracy is : 0.6578
# Epoch 11, CIFAR-10 Batch 3:  batch loss is :  0.391213
# batch_accuracy accuracy is : 0.631
# Epoch 11, CIFAR-10 Batch 4:  batch loss is :  0.472437
# batch_accuracy accuracy is : 0.657
# Epoch 11, CIFAR-10 Batch 5:  batch loss is :  0.439977
# batch_accuracy accuracy is : 0.6422
# Epoch 12, CIFAR-10 Batch 1:  batch loss is :  0.438234
# batch_accuracy accuracy is : 0.6656
# Epoch 12, CIFAR-10 Batch 2:  batch loss is :  0.371597
# batch_accuracy accuracy is : 0.6644
# Epoch 12, CIFAR-10 Batch 3:  batch loss is :  0.40872
# batch_accuracy accuracy is : 0.642
# Epoch 12, CIFAR-10 Batch 4:  batch loss is :  0.407249
# batch_accuracy accuracy is : 0.6612
# Epoch 12, CIFAR-10 Batch 5:  batch loss is :  0.448702
# batch_accuracy accuracy is : 0.6376
# Epoch 13, CIFAR-10 Batch 1:  batch loss is :  0.424272
# batch_accuracy accuracy is : 0.6596
# Epoch 13, CIFAR-10 Batch 2:  batch loss is :  0.360601
# batch_accuracy accuracy is : 0.6402
# Epoch 13, CIFAR-10 Batch 3:  batch loss is :  0.335018
# batch_accuracy accuracy is : 0.6626
# Epoch 13, CIFAR-10 Batch 4:  batch loss is :  0.341979
# batch_accuracy accuracy is : 0.68
# Epoch 13, CIFAR-10 Batch 5:  batch loss is :  0.386709
# batch_accuracy accuracy is : 0.6646
# Epoch 14, CIFAR-10 Batch 1:  batch loss is :  0.368626
# batch_accuracy accuracy is : 0.6644
# Epoch 14, CIFAR-10 Batch 2:  batch loss is :  0.317223
# batch_accuracy accuracy is : 0.6658
# Epoch 14, CIFAR-10 Batch 3:  batch loss is :  0.309401
# batch_accuracy accuracy is : 0.6768
# Epoch 14, CIFAR-10 Batch 4:  batch loss is :  0.357587
# batch_accuracy accuracy is : 0.6548
# Epoch 14, CIFAR-10 Batch 5:  batch loss is :  0.365882
# batch_accuracy accuracy is : 0.6516
# Epoch 15, CIFAR-10 Batch 1:  batch loss is :  0.304732
# batch_accuracy accuracy is : 0.6604
# Epoch 15, CIFAR-10 Batch 2:  batch loss is :  0.328201
# batch_accuracy accuracy is : 0.6454
# Epoch 15, CIFAR-10 Batch 3:  batch loss is :  0.299663
# batch_accuracy accuracy is : 0.6792
# Epoch 15, CIFAR-10 Batch 4:  batch loss is :  0.337115
# batch_accuracy accuracy is : 0.6654
# Epoch 15, CIFAR-10 Batch 5:  batch loss is :  0.312604
# batch_accuracy accuracy is : 0.6522
# Epoch 16, CIFAR-10 Batch 1:  batch loss is :  0.281097
# batch_accuracy accuracy is : 0.67
# Epoch 16, CIFAR-10 Batch 2:  batch loss is :  0.270436
# batch_accuracy accuracy is : 0.674
# Epoch 16, CIFAR-10 Batch 3:  batch loss is :  0.28102
# batch_accuracy accuracy is : 0.6818
# Epoch 16, CIFAR-10 Batch 4:  batch loss is :  0.295766
# batch_accuracy accuracy is : 0.6654
# Epoch 16, CIFAR-10 Batch 5:  batch loss is :  0.337839
# batch_accuracy accuracy is : 0.6248
# Epoch 17, CIFAR-10 Batch 1:  batch loss is :  0.324666
# batch_accuracy accuracy is : 0.6802
# Epoch 17, CIFAR-10 Batch 2:  batch loss is :  0.297346
# batch_accuracy accuracy is : 0.6586
# Epoch 17, CIFAR-10 Batch 3:  batch loss is :  0.270903
# batch_accuracy accuracy is : 0.6762
# Epoch 17, CIFAR-10 Batch 4:  batch loss is :  0.271345
# batch_accuracy accuracy is : 0.6726
# Epoch 17, CIFAR-10 Batch 5:  batch loss is :  0.271457
# batch_accuracy accuracy is : 0.6624
# Epoch 18, CIFAR-10 Batch 1:  batch loss is :  0.267304
# batch_accuracy accuracy is : 0.6816
# Epoch 18, CIFAR-10 Batch 2:  batch loss is :  0.247954
# batch_accuracy accuracy is : 0.6848
# Epoch 18, CIFAR-10 Batch 3:  batch loss is :  0.223743
# batch_accuracy accuracy is : 0.6774
# Epoch 18, CIFAR-10 Batch 4:  batch loss is :  0.242725
# batch_accuracy accuracy is : 0.6658
# Epoch 18, CIFAR-10 Batch 5:  batch loss is :  0.254894
# batch_accuracy accuracy is : 0.6714
# Epoch 19, CIFAR-10 Batch 1:  batch loss is :  0.288891
# batch_accuracy accuracy is : 0.682
# Epoch 19, CIFAR-10 Batch 2:  batch loss is :  0.230012
# batch_accuracy accuracy is : 0.678
# Epoch 19, CIFAR-10 Batch 3:  batch loss is :  0.245633
# batch_accuracy accuracy is : 0.68
# Epoch 19, CIFAR-10 Batch 4:  batch loss is :  0.242816
# batch_accuracy accuracy is : 0.6724
# Epoch 19, CIFAR-10 Batch 5:  batch loss is :  0.257481
# batch_accuracy accuracy is : 0.6618
# Epoch 20, CIFAR-10 Batch 1:  batch loss is :  0.24674
# batch_accuracy accuracy is : 0.6872
# Epoch 20, CIFAR-10 Batch 2:  batch loss is :  0.240114
# batch_accuracy accuracy is : 0.6812
# Epoch 20, CIFAR-10 Batch 3:  batch loss is :  0.245433
# batch_accuracy accuracy is : 0.6722
# Epoch 20, CIFAR-10 Batch 4:  batch loss is :  0.259413
# batch_accuracy accuracy is : 0.678
# Epoch 20, CIFAR-10 Batch 5:  batch loss is :  0.22899
# batch_accuracy accuracy is : 0.6738
# Epoch 21, CIFAR-10 Batch 1:  batch loss is :  0.217304
# batch_accuracy accuracy is : 0.6818
# Epoch 21, CIFAR-10 Batch 2:  batch loss is :  0.219102
# batch_accuracy accuracy is : 0.6556
# Epoch 21, CIFAR-10 Batch 3:  batch loss is :  0.205198
# batch_accuracy accuracy is : 0.681
# Epoch 21, CIFAR-10 Batch 4:  batch loss is :  0.217831
# batch_accuracy accuracy is : 0.6804
# Epoch 21, CIFAR-10 Batch 5:  batch loss is :  0.255218
# batch_accuracy accuracy is : 0.6574
# Epoch 22, CIFAR-10 Batch 1:  batch loss is :  0.200545
# batch_accuracy accuracy is : 0.683
# Epoch 22, CIFAR-10 Batch 2:  batch loss is :  0.189993
# batch_accuracy accuracy is : 0.687
# Epoch 22, CIFAR-10 Batch 3:  batch loss is :  0.212053
# batch_accuracy accuracy is : 0.6806
# Epoch 22, CIFAR-10 Batch 4:  batch loss is :  0.231312
# batch_accuracy accuracy is : 0.6756
# Epoch 22, CIFAR-10 Batch 5:  batch loss is :  0.25916
# batch_accuracy accuracy is : 0.6646
# Epoch 23, CIFAR-10 Batch 1:  batch loss is :  0.212832
# batch_accuracy accuracy is : 0.6874
# Epoch 23, CIFAR-10 Batch 2:  batch loss is :  0.193992
# batch_accuracy accuracy is : 0.6888
# Epoch 23, CIFAR-10 Batch 3:  batch loss is :  0.201772
# batch_accuracy accuracy is : 0.6816
# Epoch 23, CIFAR-10 Batch 4:  batch loss is :  0.212225
# batch_accuracy accuracy is : 0.6792
# Epoch 23, CIFAR-10 Batch 5:  batch loss is :  0.242283
# batch_accuracy accuracy is : 0.653
# Epoch 24, CIFAR-10 Batch 1:  batch loss is :  0.220234
# batch_accuracy accuracy is : 0.6824
# Epoch 24, CIFAR-10 Batch 2:  batch loss is :  0.198128
# batch_accuracy accuracy is : 0.6738
# Epoch 24, CIFAR-10 Batch 3:  batch loss is :  0.175207
# batch_accuracy accuracy is : 0.689
# Epoch 24, CIFAR-10 Batch 4:  batch loss is :  0.188973
# batch_accuracy accuracy is : 0.6848
# Epoch 24, CIFAR-10 Batch 5:  batch loss is :  0.223834
# batch_accuracy accuracy is : 0.662
# Epoch 25, CIFAR-10 Batch 1:  batch loss is :  0.16007
# batch_accuracy accuracy is : 0.6918
# Epoch 25, CIFAR-10 Batch 2:  batch loss is :  0.182674
# batch_accuracy accuracy is : 0.6902
# Epoch 25, CIFAR-10 Batch 3:  batch loss is :  0.184252
# batch_accuracy accuracy is : 0.6866
# Epoch 25, CIFAR-10 Batch 4:  batch loss is :  0.197217
# batch_accuracy accuracy is : 0.6818
# Epoch 25, CIFAR-10 Batch 5:  batch loss is :  0.181446
# batch_accuracy accuracy is : 0.6914
# Epoch 26, CIFAR-10 Batch 1:  batch loss is :  0.148785
# batch_accuracy accuracy is : 0.6942
# Epoch 26, CIFAR-10 Batch 2:  batch loss is :  0.187451
# batch_accuracy accuracy is : 0.6762
# Epoch 26, CIFAR-10 Batch 3:  batch loss is :  0.180845
# batch_accuracy accuracy is : 0.6804
# Epoch 26, CIFAR-10 Batch 4:  batch loss is :  0.168777
# batch_accuracy accuracy is : 0.6866
# Epoch 26, CIFAR-10 Batch 5:  batch loss is :  0.161453
# batch_accuracy accuracy is : 0.6866
# Epoch 27, CIFAR-10 Batch 1:  batch loss is :  0.139725
# batch_accuracy accuracy is : 0.6832
# Epoch 27, CIFAR-10 Batch 2:  batch loss is :  0.177848
# batch_accuracy accuracy is : 0.6694
# Epoch 27, CIFAR-10 Batch 3:  batch loss is :  0.168646
# batch_accuracy accuracy is : 0.6814
# Epoch 27, CIFAR-10 Batch 4:  batch loss is :  0.153865
# batch_accuracy accuracy is : 0.6774
# Epoch 27, CIFAR-10 Batch 5:  batch loss is :  0.192718
# batch_accuracy accuracy is : 0.6692
# Epoch 28, CIFAR-10 Batch 1:  batch loss is :  0.153744
# batch_accuracy accuracy is : 0.6898
# Epoch 28, CIFAR-10 Batch 2:  batch loss is :  0.182486
# batch_accuracy accuracy is : 0.6588
# Epoch 28, CIFAR-10 Batch 3:  batch loss is :  0.1672
# batch_accuracy accuracy is : 0.689
# Epoch 28, CIFAR-10 Batch 4:  batch loss is :  0.162011
# batch_accuracy accuracy is : 0.679
# Epoch 28, CIFAR-10 Batch 5:  batch loss is :  0.173638
# batch_accuracy accuracy is : 0.6812
# Epoch 29, CIFAR-10 Batch 1:  batch loss is :  0.155175
# batch_accuracy accuracy is : 0.6846
# Epoch 29, CIFAR-10 Batch 2:  batch loss is :  0.156374
# batch_accuracy accuracy is : 0.6738
# Epoch 29, CIFAR-10 Batch 3:  batch loss is :  0.158878
# batch_accuracy accuracy is : 0.678
# Epoch 29, CIFAR-10 Batch 4:  batch loss is :  0.176038
# batch_accuracy accuracy is : 0.6712
# Epoch 29, CIFAR-10 Batch 5:  batch loss is :  0.17713
# batch_accuracy accuracy is : 0.669
# Epoch 30, CIFAR-10 Batch 1:  batch loss is :  0.147434
# batch_accuracy accuracy is : 0.6832
# Epoch 30, CIFAR-10 Batch 2:  batch loss is :  0.149909
# batch_accuracy accuracy is : 0.6834
# Epoch 30, CIFAR-10 Batch 3:  batch loss is :  0.143674
# batch_accuracy accuracy is : 0.6932
# Epoch 30, CIFAR-10 Batch 4:  batch loss is :  0.146647
# batch_accuracy accuracy is : 0.6834
# Epoch 30, CIFAR-10 Batch 5:  batch loss is :  0.169222
# batch_accuracy accuracy is : 0.6784
# Epoch 31, CIFAR-10 Batch 1:  batch loss is :  0.150269
# batch_accuracy accuracy is : 0.6866
# Epoch 31, CIFAR-10 Batch 2:  batch loss is :  0.154905
# batch_accuracy accuracy is : 0.6938
# Epoch 31, CIFAR-10 Batch 3:  batch loss is :  0.130438
# batch_accuracy accuracy is : 0.681
# Epoch 31, CIFAR-10 Batch 4:  batch loss is :  0.143314
# batch_accuracy accuracy is : 0.681
# Epoch 31, CIFAR-10 Batch 5:  batch loss is :  0.166598
# batch_accuracy accuracy is : 0.6634
# Epoch 32, CIFAR-10 Batch 1:  batch loss is :  0.136861
# batch_accuracy accuracy is : 0.6856
# Epoch 32, CIFAR-10 Batch 2:  batch loss is :  0.145902
# batch_accuracy accuracy is : 0.6912
# Epoch 32, CIFAR-10 Batch 3:  batch loss is :  0.135187
# batch_accuracy accuracy is : 0.6884
# Epoch 32, CIFAR-10 Batch 4:  batch loss is :  0.148827
# batch_accuracy accuracy is : 0.6804
# Epoch 32, CIFAR-10 Batch 5:  batch loss is :  0.137721
# batch_accuracy accuracy is : 0.6814
# Epoch 33, CIFAR-10 Batch 1:  batch loss is :  0.137946
# batch_accuracy accuracy is : 0.6958
# Epoch 33, CIFAR-10 Batch 2:  batch loss is :  0.164694
# batch_accuracy accuracy is : 0.6912
# Epoch 33, CIFAR-10 Batch 3:  batch loss is :  0.116882
# batch_accuracy accuracy is : 0.6874
# Epoch 33, CIFAR-10 Batch 4:  batch loss is :  0.1319
# batch_accuracy accuracy is : 0.6754
# Epoch 33, CIFAR-10 Batch 5:  batch loss is :  0.157433
# batch_accuracy accuracy is : 0.6814
# Epoch 34, CIFAR-10 Batch 1:  batch loss is :  0.123908
# batch_accuracy accuracy is : 0.6972
# Epoch 34, CIFAR-10 Batch 2:  batch loss is :  0.144394
# batch_accuracy accuracy is : 0.6796
# Epoch 34, CIFAR-10 Batch 3:  batch loss is :  0.130168
# batch_accuracy accuracy is : 0.6748
# Epoch 34, CIFAR-10 Batch 4:  batch loss is :  0.136841
# batch_accuracy accuracy is : 0.6704
# Epoch 34, CIFAR-10 Batch 5:  batch loss is :  0.179943
# batch_accuracy accuracy is : 0.683
# Epoch 35, CIFAR-10 Batch 1:  batch loss is :  0.148433
# batch_accuracy accuracy is : 0.6842
# Epoch 35, CIFAR-10 Batch 2:  batch loss is :  0.149892
# batch_accuracy accuracy is : 0.6868
# Epoch 35, CIFAR-10 Batch 3:  batch loss is :  0.139001
# batch_accuracy accuracy is : 0.6838
# Epoch 35, CIFAR-10 Batch 4:  batch loss is :  0.105183
# batch_accuracy accuracy is : 0.686
# Epoch 35, CIFAR-10 Batch 5:  batch loss is :  0.138115
# batch_accuracy accuracy is : 0.6832
# Epoch 36, CIFAR-10 Batch 1:  batch loss is :  0.133883
# batch_accuracy accuracy is : 0.6868
# Epoch 36, CIFAR-10 Batch 2:  batch loss is :  0.143038
# batch_accuracy accuracy is : 0.6902
# Epoch 36, CIFAR-10 Batch 3:  batch loss is :  0.117045
# batch_accuracy accuracy is : 0.6782
# Epoch 36, CIFAR-10 Batch 4:  batch loss is :  0.129778
# batch_accuracy accuracy is : 0.6802
# Epoch 36, CIFAR-10 Batch 5:  batch loss is :  0.129642
# batch_accuracy accuracy is : 0.6774
# Epoch 37, CIFAR-10 Batch 1:  batch loss is :  0.121963
# batch_accuracy accuracy is : 0.7014
# Epoch 37, CIFAR-10 Batch 2:  batch loss is :  0.123661
# batch_accuracy accuracy is : 0.6932
# Epoch 37, CIFAR-10 Batch 3:  batch loss is :  0.107623
# batch_accuracy accuracy is : 0.7014
# Epoch 37, CIFAR-10 Batch 4:  batch loss is :  0.116166
# batch_accuracy accuracy is : 0.6882
# Epoch 37, CIFAR-10 Batch 5:  batch loss is :  0.119385
# batch_accuracy accuracy is : 0.6796
# Epoch 38, CIFAR-10 Batch 1:  batch loss is :  0.139736
# batch_accuracy accuracy is : 0.693
# Epoch 38, CIFAR-10 Batch 2:  batch loss is :  0.125724
# batch_accuracy accuracy is : 0.6908
# Epoch 38, CIFAR-10 Batch 3:  batch loss is :  0.123821
# batch_accuracy accuracy is : 0.6866
# Epoch 38, CIFAR-10 Batch 4:  batch loss is :  0.0922259
# batch_accuracy accuracy is : 0.6878
# Epoch 38, CIFAR-10 Batch 5:  batch loss is :  0.135618
# batch_accuracy accuracy is : 0.6682
# Epoch 39, CIFAR-10 Batch 1:  batch loss is :  0.128779
# batch_accuracy accuracy is : 0.6964
# Epoch 39, CIFAR-10 Batch 2:  batch loss is :  0.119448
# batch_accuracy accuracy is : 0.6922
# Epoch 39, CIFAR-10 Batch 3:  batch loss is :  0.114537
# batch_accuracy accuracy is : 0.6852
# Epoch 39, CIFAR-10 Batch 4:  batch loss is :  0.113772
# batch_accuracy accuracy is : 0.6788
# Epoch 39, CIFAR-10 Batch 5:  batch loss is :  0.113069
# batch_accuracy accuracy is : 0.6848
# Epoch 40, CIFAR-10 Batch 1:  batch loss is :  0.0965365
# batch_accuracy accuracy is : 0.6948
# Epoch 40, CIFAR-10 Batch 2:  batch loss is :  0.116695
# batch_accuracy accuracy is : 0.6918
# Epoch 40, CIFAR-10 Batch 3:  batch loss is :  0.104547
# batch_accuracy accuracy is : 0.6798
# Epoch 40, CIFAR-10 Batch 4:  batch loss is :  0.0981847
# batch_accuracy accuracy is : 0.6744
# Epoch 40, CIFAR-10 Batch 5:  batch loss is :  0.120392
# batch_accuracy accuracy is : 0.6828
# Epoch 41, CIFAR-10 Batch 1:  batch loss is :  0.100845
# batch_accuracy accuracy is : 0.687
# Epoch 41, CIFAR-10 Batch 2:  batch loss is :  0.105448
# batch_accuracy accuracy is : 0.6804
# Epoch 41, CIFAR-10 Batch 3:  batch loss is :  0.0960736
# batch_accuracy accuracy is : 0.6932
# Epoch 41, CIFAR-10 Batch 4:  batch loss is :  0.102582
# batch_accuracy accuracy is : 0.6696
# Epoch 41, CIFAR-10 Batch 5:  batch loss is :  0.110652
# batch_accuracy accuracy is : 0.6862
# Epoch 42, CIFAR-10 Batch 1:  batch loss is :  0.0978395
# batch_accuracy accuracy is : 0.6928
# Epoch 42, CIFAR-10 Batch 2:  batch loss is :  0.101281
# batch_accuracy accuracy is : 0.6944
# Epoch 42, CIFAR-10 Batch 3:  batch loss is :  0.107018
# batch_accuracy accuracy is : 0.6874
# Epoch 42, CIFAR-10 Batch 4:  batch loss is :  0.108376
# batch_accuracy accuracy is : 0.6866
# Epoch 42, CIFAR-10 Batch 5:  batch loss is :  0.129703
# batch_accuracy accuracy is : 0.677
# Epoch 43, CIFAR-10 Batch 1:  batch loss is :  0.0927199
# batch_accuracy accuracy is : 0.6928
# Epoch 43, CIFAR-10 Batch 2:  batch loss is :  0.105615
# batch_accuracy accuracy is : 0.696
# Epoch 43, CIFAR-10 Batch 3:  batch loss is :  0.100702
# batch_accuracy accuracy is : 0.692
# Epoch 43, CIFAR-10 Batch 4:  batch loss is :  0.107218
# batch_accuracy accuracy is : 0.6808
# Epoch 43, CIFAR-10 Batch 5:  batch loss is :  0.106636
# batch_accuracy accuracy is : 0.686
# Epoch 44, CIFAR-10 Batch 1:  batch loss is :  0.0935664
# batch_accuracy accuracy is : 0.699
# Epoch 44, CIFAR-10 Batch 2:  batch loss is :  0.0980453
# batch_accuracy accuracy is : 0.6858
# Epoch 44, CIFAR-10 Batch 3:  batch loss is :  0.118544
# batch_accuracy accuracy is : 0.6726
# Epoch 44, CIFAR-10 Batch 4:  batch loss is :  0.0920004
# batch_accuracy accuracy is : 0.6808
# Epoch 44, CIFAR-10 Batch 5:  batch loss is :  0.107794
# batch_accuracy accuracy is : 0.6824
# Epoch 45, CIFAR-10 Batch 1:  batch loss is :  0.100106
# batch_accuracy accuracy is : 0.6832
# Epoch 45, CIFAR-10 Batch 2:  batch loss is :  0.119998
# batch_accuracy accuracy is : 0.6814
# Epoch 45, CIFAR-10 Batch 3:  batch loss is :  0.0997817
# batch_accuracy accuracy is : 0.6864
# Epoch 45, CIFAR-10 Batch 4:  batch loss is :  0.0784201
# batch_accuracy accuracy is : 0.6848
# Epoch 45, CIFAR-10 Batch 5:  batch loss is :  0.0800566
# batch_accuracy accuracy is : 0.687
# Epoch 46, CIFAR-10 Batch 1:  batch loss is :  0.0945513
# batch_accuracy accuracy is : 0.6948
# Epoch 46, CIFAR-10 Batch 2:  batch loss is :  0.111901
# batch_accuracy accuracy is : 0.6894
# Epoch 46, CIFAR-10 Batch 3:  batch loss is :  0.0851645
# batch_accuracy accuracy is : 0.687
# Epoch 46, CIFAR-10 Batch 4:  batch loss is :  0.0922511
# batch_accuracy accuracy is : 0.6696
# Epoch 46, CIFAR-10 Batch 5:  batch loss is :  0.104682
# batch_accuracy accuracy is : 0.6824
# Epoch 47, CIFAR-10 Batch 1:  batch loss is :  0.0946351
# batch_accuracy accuracy is : 0.6916
# Epoch 47, CIFAR-10 Batch 2:  batch loss is :  0.103959
# batch_accuracy accuracy is : 0.6794
# Epoch 47, CIFAR-10 Batch 3:  batch loss is :  0.0784205
# batch_accuracy accuracy is : 0.677
# Epoch 47, CIFAR-10 Batch 4:  batch loss is :  0.100925
# batch_accuracy accuracy is : 0.6854
# Epoch 47, CIFAR-10 Batch 5:  batch loss is :  0.117312
# batch_accuracy accuracy is : 0.6776
# Epoch 48, CIFAR-10 Batch 1:  batch loss is :  0.091834
# batch_accuracy accuracy is : 0.6854
# Epoch 48, CIFAR-10 Batch 2:  batch loss is :  0.150448
# batch_accuracy accuracy is : 0.6572
# Epoch 48, CIFAR-10 Batch 3:  batch loss is :  0.0971172
# batch_accuracy accuracy is : 0.691
# Epoch 48, CIFAR-10 Batch 4:  batch loss is :  0.0986451
# batch_accuracy accuracy is : 0.6802
# Epoch 48, CIFAR-10 Batch 5:  batch loss is :  0.106672
# batch_accuracy accuracy is : 0.6722
# Epoch 49, CIFAR-10 Batch 1:  batch loss is :  0.104579
# batch_accuracy accuracy is : 0.6934
# Epoch 49, CIFAR-10 Batch 2:  batch loss is :  0.0920279
# batch_accuracy accuracy is : 0.6882
# Epoch 49, CIFAR-10 Batch 3:  batch loss is :  0.107761
# batch_accuracy accuracy is : 0.6834
# Epoch 49, CIFAR-10 Batch 4:  batch loss is :  0.0800316
# batch_accuracy accuracy is : 0.6856
# Epoch 49, CIFAR-10 Batch 5:  batch loss is :  0.114026
# batch_accuracy accuracy is : 0.6666
# Epoch 50, CIFAR-10 Batch 1:  batch loss is :  0.0808494
# batch_accuracy accuracy is : 0.6922
# Epoch 50, CIFAR-10 Batch 2:  batch loss is :  0.128003
# batch_accuracy accuracy is : 0.671
# Epoch 50, CIFAR-10 Batch 3:  batch loss is :  0.0885911
# batch_accuracy accuracy is : 0.6924
# Epoch 50, CIFAR-10 Batch 4:  batch loss is :  0.0887622
# batch_accuracy accuracy is : 0.6706
# Epoch 50, CIFAR-10 Batch 5:  batch loss is :  0.0812001
# batch_accuracy accuracy is : 0.6842

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.685546875

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
